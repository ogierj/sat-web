# %%
df = pd.read_csv('Updated_Cluster_Data_with_Descriptions.csv')
df.head(1)
# Out:
#   country  cluster_lat  cluster_lon    cons_pc  nightlights  \
# 0     eth      9.03418    38.842568  23.621166      0.38164
#
#                                place_name  \
# 0  Burkina Faso St, Addis Ababa, Ethiopia
#
#                                    Economic Position  \
# 0  Economically active with businesses contributi...
#
#                                         Demographics
# 0  Mixed-use area with residential and commercial...

# %%
fdf = df.sort_values('cons_pc',ascending=False).reset_index().drop(columns=['index'])

# %%
fdf
# Out:
#    country  cluster_lat  cluster_lon    cons_pc  nightlights  \
# 0      eth     8.954261    38.776901  30.038594     0.675716
# 1      eth     9.034180    38.842568  23.621166     0.381640
# 2      eth     9.015257    38.813750  20.499866     0.702203
# 3      eth     8.964058    38.721902  20.488550     0.634796
# 4      eth     9.052935    38.735117  18.578238     0.542717
# 5      eth     9.020116    38.733379  18.206968     0.851894
# 6      eth     8.989751    38.773653  17.768381     1.000000
# 7      eth     9.013835    38.741334  14.816839     0.918602
# 8      eth     9.047567    38.718242  14.566923     0.515056
# 9      eth     9.071813    38.729929  13.792394     0.319315
# 10     eth     8.958031    38.748086  12.825229     0.730208
# 11     eth     9.018709    38.789997  12.782309     0.880685
# 12     eth     9.061072    38.791779  12.539863     0.288456
# 13     eth     9.037509    38.737811  11.936232     0.721796
# ...

# %%
area_name = ['Bole','Burkina Faso St','ILRI campus','Jomo','Yeka','Kenenisa Avenue','Kirkos','Liberia Street','Sheh Ojele Street','Gulele','Nefassik Lafto','Geja Sefer','Guele','Riche Kirkos subcity','Kotebe','Nefas Silk Fafto']
len(area_name)
# Out:
# 16

# %%
fdf['area_name'] = area_name

# %%
fdf
# Out:
#    country  cluster_lat  cluster_lon    cons_pc  nightlights  \
# 0      eth     8.954261    38.776901  30.038594     0.675716
# 1      eth     9.034180    38.842568  23.621166     0.381640
# 2      eth     9.015257    38.813750  20.499866     0.702203
# 3      eth     8.964058    38.721902  20.488550     0.634796
# 4      eth     9.052935    38.735117  18.578238     0.542717
# 5      eth     9.020116    38.733379  18.206968     0.851894
# 6      eth     8.989751    38.773653  17.768381     1.000000
# 7      eth     9.013835    38.741334  14.816839     0.918602
# 8      eth     9.047567    38.718242  14.566923     0.515056
# 9      eth     9.071813    38.729929  13.792394     0.319315
# 10     eth     8.958031    38.748086  12.825229     0.730208
# 11     eth     9.018709    38.789997  12.782309     0.880685
# 12     eth     9.061072    38.791779  12.539863     0.288456
# 13     eth     9.037509    38.737811  11.936232     0.721796
# ...

# %%
fdf.drop(columns=['country','nightlights','place_name'],inplace=True)

# %%
fdf
# Out:
#     cluster_lat  cluster_lon    cons_pc  \
# 0      8.954261    38.776901  30.038594
# 1      9.034180    38.842568  23.621166
# 2      9.015257    38.813750  20.499866
# 3      8.964058    38.721902  20.488550
# 4      9.052935    38.735117  18.578238
# 5      9.020116    38.733379  18.206968
# 6      8.989751    38.773653  17.768381
# 7      9.013835    38.741334  14.816839
# 8      9.047567    38.718242  14.566923
# 9      9.071813    38.729929  13.792394
# 10     8.958031    38.748086  12.825229
# 11     9.018709    38.789997  12.782309
# 12     9.061072    38.791779  12.539863
# 13     9.037509    38.737811  11.936232
# 14     9.023574    38.784249  11.709447
# 15     8.957485    38.762128  10.622940
#
#                                     Economic Position  \
# 0   Bole is one of the most affluent districts in ...
# 1   Economically active with businesses contributi...
# 2   Benefits economically from the presence of the...
# ...
